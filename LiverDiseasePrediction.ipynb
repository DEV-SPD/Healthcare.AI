# %% [markdown]
# # DATA UNDERSTANDING

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv',encoding = 'unicode_escape')

# %%
df.shape
# Out:
# (30691, 11)

# %%
df.head()
# Out:
#     Age  Gender  Total_Bilirubin  Direct_Bilirubin    AAP   SAA_1  SAA_2  \
# 0  65.0  Female              0.7               0.1  187.0    16.0   18.0
# 1  62.0    Male             10.9               5.5  699.0    64.0  100.0
# 2  62.0    Male              7.3               4.1  490.0    60.0   68.0
# 3  58.0    Male              1.0               0.4  182.0    14.0   20.0
# 4  72.0    Male              3.9               2.0  195.0    27.0   59.0
#
#    Total_Protiens   ALB_Albumin  A/G_RATIO  Result
# 0             6.8           3.3       0.90       1
# 1             7.5           3.2       0.74       1
# 2             7.0           3.3       0.89       1
# 3             6.8           3.4       1.00       1
# 4             7.3           2.4       0.40       1

# %%
df.tail()
# Out:
#         Age  Gender  Total_Bilirubin  Direct_Bilirubin    AAP   SAA_1  SAA_2  \
# 30686  50.0    Male              2.2               1.0  610.0    17.0   28.0
# 30687  55.0    Male              2.9               1.3  482.0    22.0   34.0
# 30688  54.0    Male              6.8               3.0  542.0   116.0   66.0
# 30689  48.0  Female              1.9               1.0  231.0    16.0   55.0
# 30690  30.0    Male              3.1               1.6  253.0    80.0  406.0
#
#        Total_Protiens   ALB_Albumin  A/G_RATIO  Result
# 30686             7.3           2.6       0.55       1
# 30687             7.0           2.4       0.50       1
# 30688             6.4           3.1       0.90       1
# 30689             4.3           1.6       0.60       1
# 30690             6.8           3.9       1.30       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30691 entries, 0 to 30690
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               30689 non-null  float64
#  1   Gender            29789 non-null  object
#  2   Total_Bilirubin   30043 non-null  float64
#  3   Direct_Bilirubin  30130 non-null  float64
#  4    AAP              29895 non-null  float64
#  5    SAA_1            30153 non-null  float64
#  6   SAA_2             30229 non-null  float64
#  7   Total_Protiens    30228 non-null  float64
#  8    ALB_Albumin      30197 non-null  float64
#  9   A/G_RATIO         30132 non-null  float64
#  10  Result            30691 non-null  int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# Age                   2
# Gender              902
# Total_Bilirubin     648
# Direct_Bilirubin    561
#  AAP                796
#  SAA_1              538
# SAA_2               462
# Total_Protiens      463
#  ALB_Albumin        494
# A/G_RATIO           559
# Result                0
# dtype: int64

# %%
df.nunique()
# Out:
# Age                  77
# Gender                2
# Total_Bilirubin     113
# Direct_Bilirubin     80
#  AAP                263
#  SAA_1              152
# SAA_2               177
# Total_Protiens       58
#  ALB_Albumin         40
# A/G_RATIO            69
# Result                2
# dtype: int64

# %%
df.corr(method='pearson')
# Out:
# C:\Users\sibap\AppData\Local\Temp\ipykernel_20576\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                        Age  Total_Bilirubin  Direct_Bilirubin       AAP  \
# Age               1.000000        -0.001600         -0.001521 -0.000761
# Total_Bilirubin  -0.001600         1.000000          0.886987  0.197183
# Direct_Bilirubin -0.001521         0.886987          1.000000  0.220954
#  AAP             -0.000761         0.197183          0.220954  1.000000
#  SAA_1            0.000659         0.207893          0.222759  0.124099
# SAA_2             0.006104         0.240273          0.256200  0.160690
# Total_Protiens   -0.007951         0.001185          0.006474 -0.022321
#  ALB_Albumin     -0.015164        -0.222522         -0.229106 -0.161060
# A/G_RATIO        -0.018056        -0.197978         -0.189414 -0.228583
# Result           -0.004759        -0.225061         -0.249538 -0.183356
#
#                      SAA_1     SAA_2  Total_Protiens   ALB_Albumin  A/G_RATIO  \
# Age               0.000659  0.006104       -0.007951     -0.015164  -0.018056
# Total_Bilirubin   0.207893  0.240273        0.001185     -0.222522  -0.197978
# Direct_Bilirubin  0.222759  0.256200        0.006474     -0.229106  -0.189414
#  AAP              0.124099  0.160690       -0.022321     -0.161060  -0.228583
#  SAA_1            1.000000  0.783411       -0.041400     -0.026346  -0.002433
# SAA_2             0.783411  1.000000       -0.024501     -0.083383  -0.066912
# Total_Protiens   -0.041400 -0.024501        1.000000      0.775607   0.226314
#  ALB_Albumin     -0.026346 -0.083383        0.775607      1.000000   0.682759
# A/G_RATIO        -0.002433 -0.066912        0.226314      0.682759   1.000000
# Result           -0.165914 -0.158660        0.030370      0.160346   0.158350
#
#                     Result
# Age              -0.004759
# Total_Bilirubin  -0.225061
# Direct_Bilirubin -0.249538
#  AAP             -0.183356
#  SAA_1           -0.165914
# SAA_2            -0.158660
# Total_Protiens    0.030370
#  ALB_Albumin      0.160346
# A/G_RATIO         0.158350
# Result            1.000000

# %%
df.duplicated().sum()
# Out:
# 11323

# %% [markdown]
# # DATA PREPARATION

# %%
a = df.columns

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin', 'AAP', 'SAA_1',
#        'SAA_2', 'Total_Protiens', 'ALB_Albumin', 'A/G_RATIO', 'Result'],
#       dtype='object')

# %%
df['AAP']
# Out:
# 0        187.0
# 1        699.0
# 2        490.0
# 3        182.0
# 4        195.0
#          ...
# 30686    610.0
# 30687    482.0
# 30688    542.0
# 30689    231.0
# 30690    253.0
# Name: AAP, Length: 30691, dtype: float64

# %%
x = df.drop(columns = ['Result'])
y = df.Result

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.09,random_state=36)

# %%
X_train
# Out:
#         Age  Gender  Total_Bilirubin  Direct_Bilirubin    AAP   SAA_1  SAA_2  \
# 21655  58.0    Male              3.1               1.6  253.0    80.0  406.0
# 8380   48.0  Female              0.6               0.1  289.0    38.0   30.0
# 18513  40.0  Female              0.6               0.1  175.0    48.0   34.0
# 6193   75.0    Male              0.9               0.2  165.0    26.0   29.0
# 4174   51.0     NaN              5.8               2.7  204.0     NaN  400.0
# ...     ...     ...              ...               ...    ...     ...    ...
# 7329   31.0    Male              0.7               0.2  152.0    21.0   25.0
# 19368  65.0    Male              0.8               0.2  201.0    18.0   22.0
# 25502  26.0    Male              1.9               0.8  170.0    36.0   43.0
# 610    55.0    Male              6.2               3.0  240.0  1680.0  850.0
# 29317  43.0  Female              4.0               2.5  275.0   382.0  330.0
#
#        Total_Protiens  ALB_Albumin  A/G_RATIO
# 21655             6.8          3.9       1.30
# 8380              4.8          2.0       0.70
# 18513             6.0          3.7       1.60
# 6193              8.5          4.4       1.00
# 4174              7.0          3.0       0.70
# ...               ...          ...        ...
# 7329              5.9          3.1       1.10
# 19368             5.4          2.9       1.10
# 25502             3.8          1.4       0.58
# 610               7.2          4.0       1.20
# 29317             7.5          4.0       1.10
#
# [27928 rows x 10 columns]

# %%
#Handling Missing Values
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_features = ['Age','Total_Bilirubin','Direct_Bilirubin','AAP','SAA_1','SAA_2','Total_Protiens','ALB_Albumin','A/G_RATIO']
cat_features = ['Gender']

imputer_num = SimpleImputer(strategy='mean')
imputer_cat = SimpleImputer(strategy='most_frequent')

encoder = OneHotEncoder()

# %%
num_pipeline = Pipeline(
    steps=[
        ('imputer1',imputer_num)
    ]
) 

cat_pipeline = Pipeline(
   steps = [
       ('imputer2',imputer_cat),
       ('encoder',encoder)
       
   ]
)


transformer = ColumnTransformer(
     transformers = [
         ('pipe1',num_pipeline,num_features),
         ('pipe2',cat_pipeline,cat_features)
     ]
)

# %%
transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('pipe1',
#                                  Pipeline(steps=[('imputer1',
#                                                   SimpleImputer())]),
#                                  ['Age', 'Total_Bilirubin', 'Direct_Bilirubin',
#                                   'AAP', 'SAA_1', 'SAA_2', 'Total_Protiens',
#                                   'ALB_Albumin', 'A/G_RATIO']),
#                                 ('pipe2',
#                                  Pipeline(steps=[('imputer2',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder', OneHotEncoder())]),
#                                  ['Gender'])])

# %%
X_train = transformer.transform(X_train)

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
X_test = transformer.fit_transform(X_test)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
#Top 5 rows of dataframe
df.head()
# Out:
#     Age  Gender  Total_Bilirubin  Direct_Bilirubin    AAP  SAA_1  SAA_2  \
# 0  65.0  Female              0.7               0.1  187.0   16.0   18.0
# 1  62.0    Male             10.9               5.5  699.0   64.0  100.0
# 2  62.0    Male              7.3               4.1  490.0   60.0   68.0
# 3  58.0    Male              1.0               0.4  182.0   14.0   20.0
# 4  72.0    Male              3.9               2.0  195.0   27.0   59.0
#
#    Total_Protiens  ALB_Albumin  A/G_RATIO  Result
# 0             6.8          3.3       0.90       1
# 1             7.5          3.2       0.74       1
# 2             7.0          3.3       0.89       1
# 3             6.8          3.4       1.00       1
# 4             7.3          2.4       0.40       1

# %%
#Last 5 rows of dataframe
df.tail()
# Out:
#         Age  Gender  Total_Bilirubin  Direct_Bilirubin    AAP  SAA_1  SAA_2  \
# 30686  50.0    Male              2.2               1.0  610.0   17.0   28.0
# 30687  55.0    Male              2.9               1.3  482.0   22.0   34.0
# 30688  54.0    Male              6.8               3.0  542.0  116.0   66.0
# 30689  48.0  Female              1.9               1.0  231.0   16.0   55.0
# 30690  30.0    Male              3.1               1.6  253.0   80.0  406.0
#
#        Total_Protiens  ALB_Albumin  A/G_RATIO  Result
# 30686             7.3          2.6       0.55       1
# 30687             7.0          2.4       0.50       1
# 30688             6.4          3.1       0.90       1
# 30689             4.3          1.6       0.60       1
# 30690             6.8          3.9       1.30       1

# %%
#getting brief statistical information about dataframe
df.describe()
# Out:
#                 Age  Total_Bilirubin  Direct_Bilirubin           AAP  \
# count  30689.000000     30043.000000      30130.000000  29895.000000
# mean      44.107205         3.370319          1.528042    289.075364
# std       15.981043         6.255522          2.869592    238.537589
# min        4.000000         0.400000          0.100000     63.000000
# 25%       32.000000         0.800000          0.200000    175.000000
# 50%       45.000000         1.000000          0.300000    209.000000
# 75%       55.000000         2.700000          1.300000    298.000000
# max       90.000000        75.000000         19.700000   2110.000000
#
#               SAA_1         SAA_2  Total_Protiens   ALB_Albumin     A/G_RATIO  \
# count  30153.000000  30229.000000    30228.000000  30197.000000  30132.000000
# mean      81.488641    111.469979        6.480237      3.130142      0.943467
# std      182.158850    280.851078        1.081980      0.792281      0.323164
# min       10.000000     10.000000        2.700000      0.900000      0.300000
# 25%       23.000000     26.000000        5.800000      2.600000      0.700000
# 50%       35.000000     42.000000        6.600000      3.100000      0.900000
# 75%       62.000000     88.000000        7.200000      3.800000      1.100000
# max     2000.000000   4929.000000        9.600000      5.500000      2.800000
#
#              Result
# count  30691.000000
# mean       1.285882
# std        0.451841
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000

# %%
df.groupby('Gender').Result.value_counts()
# Out:
# Gender  Result
# Female  1          5553
#         2          2250
# Male    1         15742
#         2          6244
# Name: Result, dtype: int64

# %%
sns.barplot(x=df.Gender,y=df.Result)
# Out:
# <Axes: xlabel='Gender', ylabel='Result'>

# %%
df.groupby('Result').Age.mean()
# Out:
# Result
# 1    44.155327
# 2    43.987007
# Name: Age, dtype: float64

# %%
sns.pairplot(df)

# %% [markdown]
# # DATA MODELLING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
models=[RandomForestClassifier(),DecisionTreeClassifier(),LogisticRegression(max_iter=100000),BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=9000,max_samples=0.9999,oob_score=True,random_state=True)]

# %%
for model in models:
    model.fit(X_train,y_train)
    print(f"Accuracy score of {model} is: {model.score(X_test,y_test)*100}")
    print("*************************************************************")
# Out:
# Accuracy score of RandomForestClassifier() is: 99.74665218964893
# *************************************************************
# Accuracy score of DecisionTreeClassifier() is: 99.05899384726746
# *************************************************************
# Accuracy score of LogisticRegression(max_iter=100000) is: 72.09554831704669
# *************************************************************
# E:\Program Files\Anaconda\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Accuracy score of BaggingClassifier(base_estimator=DecisionTreeClassifier(), max_samples=0.9999,
#                   n_estimators=9000, oob_score=True, random_state=True) is: 99.3485342019544
# *************************************************************

# %%
models2 = [GradientBoostingClassifier(n_estimators=3000,learning_rate=2500),AdaBoostClassifier(n_estimators=3000,learning_rate=2500)]

for model in models2:
    model.fit(X_train,y_train)
    print(f"Accuracy score of {model} is: {model.score(X_test,y_test)*100}")
    print("*************************************************************")
# Out:
# Accuracy score of GradientBoostingClassifier(learning_rate=2500, n_estimators=3000) is: 67.53528773072746
# *************************************************************
# Accuracy score of AdaBoostClassifier(learning_rate=2500, n_estimators=3000) is: 70.86500180962722
# *************************************************************
# E:\Program Files\Anaconda\lib\site-packages\sklearn\ensemble\_weight_boosting.py:627: RuntimeWarning: overflow encountered in exp
#   sample_weight *= np.exp(
# C:\Users\sibap\AppData\Local\Temp\ipykernel_20576\1888072823.py:4: UserWarning: Sample weights have reached infinite values, at iteration 0, causing overflow. Iterations stopped. Try lowering the learning rate.
#   model.fit(X_train,y_train)

# %% [markdown]
# # NOTE:-
# BEST SUITABLE ML ALGORITHM TO BUILD MODEL IS HENCE RANDOM FOREST CLASSIFIER.

# %%
model = RandomForestClassifier(n_estimators=4900)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=4900)

# %% [markdown]
# # MODEL EVALUATION

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict(X_test)

# %%
print(f"Accuracy Score Obtained is : {accuracy_score(y_test,y_pred)*100} %")
# Out:
# Accuracy Score Obtained is : 99.6742671009772 %

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1963
#            2       0.99      1.00      0.99       800
#
#     accuracy                           1.00      2763
#    macro avg       1.00      1.00      1.00      2763
# weighted avg       1.00      1.00      1.00      2763

# %% [markdown]
# # SAVING MODELS

# %%
import pickle
import bz2
with bz2.BZ2File("Liver_Disease",'wb') as f:
    pickle.dump(model,f)
    f.close()

# %% [markdown]
# # AUTHOR ~ SibaPrasadDas
